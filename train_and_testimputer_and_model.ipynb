# %% [markdown]
# <a href="https://colab.research.google.com/github/yousenwang/DeepCOOH/blob/master/train_and_testimputer_and_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow_model_optimization
# Out:
# ...
#      |████████████████████████████████| 174kB 11.5MB/s
# ...
#      |████████████████████████████████| 296kB 11.3MB/s
# ...

# %%
# !python train_imputer_and_model.py
# Out:
# sys:1: DtypeWarning: Columns (162) have mixed types.Specify dtype option on import or set low_memory=False.
# (12834, 164)
# load_is_cate_dict Counter({0: 164, 1: 12})
# ['Line', 'Z_Capacity_GROUP', 'SerialNo', 'Z_SB_PPM_GROUP', 'Z_COA_PPM_GROUP', 'SerialNo_SPCData_CP6_14', 'SPCLotNo_14', 'SerialNo_SPCData_CP6_15', 'SPCLotNo_15', 'Z_SB_PPM_GROUP_ID', 'Z_COA_PPM_GROUP_ID', 'Z_Capacity_GROUP_ID']
# the number of categorical features dropped: 7
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# train: (11434, 156), test: (1400, 156)
# get_labeled_dat
# (736, 156)
# StandardScaler(copy=True, with_mean=True, with_std=True) saved.
# ...

# %%
# !python test_imputer_and_model.py
# Out:
# sys:1: DtypeWarning: Columns (162) have mixed types.Specify dtype option on import or set low_memory=False.
# (12834, 164)
# load_is_cate_dict Counter({0: 164, 1: 12})
# ['Line', 'Z_Capacity_GROUP', 'SerialNo', 'Z_SB_PPM_GROUP', 'Z_COA_PPM_GROUP', 'SerialNo_SPCData_CP6_14', 'SPCLotNo_14', 'SerialNo_SPCData_CP6_15', 'SPCLotNo_15', 'Z_SB_PPM_GROUP_ID', 'Z_COA_PPM_GROUP_ID', 'Z_Capacity_GROUP_ID']
# the number of categorical features dropped: 7
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# train: (11434, 156), test: (1400, 156)
# KNNImputer(add_indicator=False, copy=True, metric='nan_euclidean',
#            missing_values=nan, n_neighbors=5, weights='distance') loaded
# get_labeled_dat
# (135, 156)
# ...
